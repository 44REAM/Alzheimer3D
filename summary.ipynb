# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
test_df = pd.read_csv("results/test.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
# r.to_csv("summary_test.csv", float_format='%.2f')
r
# Out:
#                                    fold     acc    bacc  precision  \
# modality model    checkpoint_type
# FA       resnet10 bacc              2.0  0.6538  0.6930     0.3498
#          vgg11    bacc              2.0  0.6784  0.7420     0.3848
# MD       resnet10 bacc              2.0  0.6268  0.6798     0.3278
#          vgg11    bacc              2.0  0.7094  0.6876     0.3838
# PT       resnet10 bacc              2.0  0.7178  0.7520     0.4206
#          vgg11    bacc              2.0  0.6824  0.7224     0.3750
# nPT      resnet10 bacc              2.0  0.7484  0.8046     0.4516
#          vgg11    bacc              2.0  0.6824  0.7370     0.3976
#
#                                    specificity  recall      f1  rocauc
# modality model    checkpoint_type
# FA       resnet10 bacc                0.625974    0.76  0.4730  0.7890
#          vgg11    bacc                0.633766    0.85  0.5246  0.8082
# MD       resnet10 bacc                0.589610    0.77  0.4566  0.7696
#          vgg11    bacc                0.724675    0.65  0.4802  0.7678
# PT       resnet10 bacc                0.693506    0.81  0.5430  0.8448
#          vgg11    bacc                0.654545    0.79  0.5062  0.8004
# nPT      resnet10 bacc                0.709091    0.90  0.5992  0.8506
#          vgg11    bacc                0.644156    0.83  0.5240  0.8084

# %%
test_df = pd.read_csv("results/val.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r.to_csv("summary_val.csv", float_format='%.2f')
r
# Out:
#                                    fold     acc    bacc  precision  \
# modality model    checkpoint_type
# FA       resnet10 bacc              2.0  0.7420  0.7574     0.4436
#          vgg11    bacc              2.0  0.7406  0.7686     0.4496
# MD       resnet10 bacc              2.0  0.7094  0.7346     0.4058
#          vgg11    bacc              2.0  0.7500  0.7314     0.4390
# PT       resnet10 bacc              2.0  0.7130  0.7206     0.4164
#          vgg11    bacc              2.0  0.7072  0.7144     0.4046
# nPT      resnet10 bacc              2.0  0.7282  0.7466     0.4226
#          vgg11    bacc              2.0  0.7106  0.7270     0.4196
#
#                                    specificity  recall      f1  rocauc
# modality model    checkpoint_type
# FA       resnet10 bacc                0.731172  0.7834  0.5610  0.8092
#          vgg11    bacc                0.720824  0.8168  0.5712  0.8038
# MD       resnet10 bacc                0.691434  0.7780  0.5290  0.7890
#          vgg11    bacc                0.763096  0.7000  0.5380  0.7884
# PT       resnet10 bacc                0.707568  0.7332  0.5208  0.7652
#          vgg11    bacc                0.701707  0.7278  0.5102  0.7512
# nPT      resnet10 bacc                0.715039  0.7778  0.5452  0.7944
#          vgg11    bacc                0.698712  0.7556  0.5276  0.7804

# %%
test_df = pd.read_csv("results/test_covid.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
test_df
# Out:
#        model  modality checkpoint_type  fold    acc   bacc  precision  \
# 1      vgg11  fdt_part            bacc     0  0.889  0.929      0.667
# 3   resnet10  fdt_part            bacc     0  1.000  1.000      1.000
# 5      vgg11  fdt_part            bacc     1  1.000  1.000      1.000
# 7   resnet10  fdt_part            bacc     1  0.667  0.786      0.400
# 9      vgg11  fdt_part            bacc     2  1.000  1.000      1.000
# 11  resnet10  fdt_part            bacc     2  1.000  1.000      1.000
# 13     vgg11  fdt_part            bacc     3  1.000  1.000      1.000
# 15  resnet10  fdt_part            bacc     3  1.000  1.000      1.000
# 17     vgg11  fdt_part            bacc     4  1.000  1.000      1.000
# 19  resnet10  fdt_part            bacc     4  0.889  0.750      1.000
#
#     specificity  recall     f1  rocauc
# 1      0.857143     1.0  0.800     1.0
# 3      1.000000     1.0  1.000     1.0
# 5      1.000000     1.0  1.000     1.0
# 7      0.571429     1.0  0.571     1.0
# 9      1.000000     1.0  1.000     1.0
# 11     1.000000     1.0  1.000     1.0
# 13     1.000000     1.0  1.000     1.0
# 15     1.000000     1.0  1.000     1.0
# 17     1.000000     1.0  1.000     1.0
# 19     1.000000     0.5  0.667     1.0

# %%
test_df = pd.read_csv("results/test_covid.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r.to_csv("summary_test_covid.csv", float_format='%.2f')
r
# Out:
#                                    fold     acc    bacc  precision  \
# modality model    checkpoint_type
# fdt_part resnet10 bacc              2.0  0.9112  0.9072     0.8800
#          vgg11    bacc              2.0  0.9778  0.9858     0.9334
#
#                                    specificity  recall      f1  rocauc
# modality model    checkpoint_type
# fdt_part resnet10 bacc                0.914286     0.9  0.8476     1.0
#          vgg11    bacc                0.971429     1.0  0.9600     1.0

# %%
test_df = pd.read_csv("results/val_covid.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r.to_csv("summary_val_covid.csv", float_format='%.2f')
r
# Out:
#                                    fold     acc  bacc  precision  specificity  \
# modality model    checkpoint_type
# fdt_part resnet10 bacc              2.0  0.9714  0.98     0.9334         0.96
#          vgg11    bacc              2.0  0.9714  0.98     0.9334         0.96
#
#                                    recall    f1  rocauc
# modality model    checkpoint_type
# fdt_part resnet10 bacc                1.0  0.96    0.98
#          vgg11    bacc                1.0  0.96    0.96

# %%
test_df = pd.read_csv("results/test_KidLead.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
test_df
# Out:
#         model modality checkpoint_type  fold    acc   bacc  precision  \
# 1       vgg11       FA            bacc     0  0.935  0.856      0.750
# 3    resnet10       FA            bacc     0  0.903  0.731      0.667
# 5       vgg11       FA            bacc     1  0.806  0.782      0.375
# 7    resnet10       FA            bacc     1  0.839  0.907      0.444
# 9       vgg11       FA            bacc     2  0.806  0.782      0.375
# ..        ...      ...             ...   ...    ...    ...        ...
# 131  resnet10  T2s_R2s            bacc     2  0.903  0.625      1.000
# 133     vgg11  T2s_R2s            bacc     3  0.968  0.875      1.000
# 135  resnet10  T2s_R2s            bacc     3  0.968  0.981      0.800
# 137     vgg11  T2s_R2s            bacc     4  0.903  0.731      0.667
# 139  resnet10  T2s_R2s            bacc     4  0.903  0.731      0.667
#
#      specificity  recall     f1  rocauc
# 1       0.962963    0.75  0.750   0.954
# 3       0.962963    0.50  0.571   0.944
# 5       0.814815    0.75  0.500   0.935
# 7       0.814815    1.00  0.615   0.907
# 9       0.814815    0.75  0.500   0.935
# ..           ...     ...    ...     ...
# 131     1.000000    0.25  0.400   0.926
# 133     1.000000    0.75  0.857   0.991
# 135     0.962963    1.00  0.889   0.972
# 137     0.962963    0.50  0.571   0.963
# 139     0.962963    0.50  0.571   0.944
#
# [70 rows x 11 columns]

# %%
test_df = pd.read_csv("results/test_KidLead.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                          fold     acc    bacc  precision  \
# modality       model    checkpoint_type
# FA             resnet10 bacc              2.0  0.8580  0.8330     0.5244
#                vgg11    bacc              2.0  0.8320  0.7756     0.4880
# MD             resnet10 bacc              2.0  0.8322  0.7970     0.5168
#                vgg11    bacc              2.0  0.8902  0.7880     0.5600
# PT             resnet10 bacc              2.0  0.8580  0.8118     0.5150
#                vgg11    bacc              2.0  0.8902  0.7450     0.6002
# T2s_1st_volume resnet10 bacc              2.0  0.8708  0.7978     0.5754
#                vgg11    bacc              2.0  0.8902  0.7662     0.5944
# T2s_R2s        resnet10 bacc              2.0  0.8902  0.8090     0.6684
#                vgg11    bacc              2.0  0.9160  0.8026     0.7034
# nPT            resnet10 bacc              2.0  0.8578  0.8332     0.5100
#                vgg11    bacc              2.0  0.9030  0.7738     0.6368
# nodif          resnet10 bacc              2.0  0.7742  0.7426     0.3544
#                vgg11    bacc              2.0  0.8514  0.7870     0.4858
#
#                                          specificity  recall      f1  rocauc
# modality       model    checkpoint_type
# FA             resnet10 bacc                0.866667    0.80  0.5886  0.9480
#                vgg11    bacc                0.851852    0.70  0.5442  0.9388
# MD             resnet10 bacc                0.844444    0.75  0.5618  0.9204
#                vgg11    bacc                0.925926    0.65  0.6002  0.9074
# PT             resnet10 bacc                0.874074    0.75  0.5772  0.9442
#                vgg11    bacc                0.940741    0.55  0.5626  0.8814
# T2s_1st_volume resnet10 bacc                0.896296    0.70  0.5940  0.9350
#                vgg11    bacc                0.933333    0.60  0.5768  0.9056
# T2s_R2s        resnet10 bacc                0.918519    0.70  0.6054  0.9406
#                vgg11    bacc                0.955556    0.65  0.6690  0.9074
# nPT            resnet10 bacc                0.866667    0.80  0.5984  0.9408
#                vgg11    bacc                0.948148    0.60  0.6118  0.9054
# nodif          resnet10 bacc                0.785185    0.70  0.4314  0.9016
#                vgg11    bacc                0.874074    0.70  0.5508  0.9370

# %%
test_df = pd.read_csv("results/val_KidLead.csv")
test_df = test_df[test_df["checkpoint_type"] == 'bacc']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                          fold     acc    bacc  precision  \
# modality       model    checkpoint_type
# FA             resnet10 bacc              2.0  0.8052  0.8030     0.5646
#                vgg11    bacc              2.0  0.9022  0.9156     0.6608
# MD             resnet10 bacc              2.0  0.8716  0.8696     0.7428
#                vgg11    bacc              2.0  0.9516  0.9440     0.7900
# PT             resnet10 bacc              2.0  0.8716  0.8984     0.6496
#                vgg11    bacc              2.0  0.9756  0.9574     0.9000
# T2s_1st_volume resnet10 bacc              2.0  0.8866  0.8494     0.6700
#                vgg11    bacc              2.0  0.9516  0.9152     0.8334
# T2s_R2s        resnet10 bacc              2.0  0.8950  0.9114     0.6308
#                vgg11    bacc              2.0  0.9436  0.9394     0.8000
# nPT            resnet10 bacc              2.0  0.8872  0.8788     0.6666
#                vgg11    bacc              2.0  0.9430  0.9100     0.7900
# nodif          resnet10 bacc              2.0  0.7822  0.8476     0.4624
#                vgg11    bacc              2.0  0.9106  0.9206     0.7166
#
#                                          specificity  recall      f1  rocauc
# modality       model    checkpoint_type
# FA             resnet10 bacc                0.806494  0.8002  0.5710  0.8882
#                vgg11    bacc                0.898268  0.9334  0.7318  0.9188
# MD             resnet10 bacc                0.872727  0.8668  0.7240  0.8888
#                vgg11    bacc                0.954545  0.9334  0.8314  0.9624
# PT             resnet10 bacc                0.863636  0.9334  0.7048  0.9012
#                vgg11    bacc                0.981818  0.9334  0.9028  0.9816
# T2s_1st_volume resnet10 bacc                0.898701  0.8002  0.6762  0.8640
#                vgg11    bacc                0.963636  0.8668  0.8268  0.9286
# T2s_R2s        resnet10 bacc                0.890043  0.9334  0.7104  0.9100
#                vgg11    bacc                0.945455  0.9334  0.8268  0.9472
# nPT            resnet10 bacc                0.890909  0.8668  0.6868  0.9064
#                vgg11    bacc                0.953680  0.8668  0.7914  0.9216
# nodif          resnet10 bacc                0.761905  0.9334  0.5524  0.9040
#                vgg11    bacc                0.907792  0.9334  0.7648  0.9190

# %%
test_df = pd.read_csv("results/test_KidLeadRegression.csv")
test_df = test_df[test_df["checkpoint_type"] == 'rmse']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                          fold    rmse     mae    mape      r2
# modality       model    checkpoint_type
# FA             resnet10 rmse              2.0  5.0218  3.2544  0.6112 -0.0224
#                vgg11    rmse              2.0  4.0020  2.5818  0.5042  0.3492
# MD             resnet10 rmse              2.0  5.0704  3.1500  0.5612 -0.0424
#                vgg11    rmse              2.0  4.1486  2.5924  0.4946  0.3012
# PT             resnet10 rmse              2.0  5.0262  3.2672  0.6154 -0.0240
#                vgg11    rmse              2.0  3.9908  2.5608  0.4984  0.3524
# T2s_1st_volume resnet10 rmse              2.0  5.0460  3.2152  0.5920 -0.0322
#                vgg11    rmse              2.0  4.0718  2.5980  0.4904  0.3272
# T2s_R2s        resnet10 rmse              2.0  5.0560  3.2506  0.6038 -0.0364
#                vgg11    rmse              2.0  4.0722  2.6180  0.5008  0.3258
# nPT            resnet10 rmse              2.0  5.0412  3.2518  0.6076 -0.0302
#                vgg11    rmse              2.0  3.9878  2.5282  0.4808  0.3542
# nodif          resnet10 rmse              2.0  5.0352  3.2062  0.5896 -0.0276
#                vgg11    rmse              2.0  4.0012  2.4914  0.4626  0.3498

# %%
test_df = pd.read_csv("results/val_KidLeadRegression.csv")
test_df = test_df[test_df["checkpoint_type"] == 'rmse']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                          fold    rmse     mae    mape  \
# modality       model    checkpoint_type
# FA             resnet10 rmse              2.0  4.6888  3.1416  0.7596
#                vgg11    rmse              2.0  3.8260  2.4360  0.5856
# MD             resnet10 rmse              2.0  4.6910  2.9830  0.6920
#                vgg11    rmse              2.0  3.8394  2.5398  0.6504
# PT             resnet10 rmse              2.0  4.7008  3.1768  0.7720
#                vgg11    rmse              2.0  3.8494  2.5188  0.6312
# T2s_1st_volume resnet10 rmse              2.0  4.6990  3.1194  0.7428
#                vgg11    rmse              2.0  3.9074  2.5990  0.6396
# T2s_R2s        resnet10 rmse              2.0  4.7148  3.1786  0.7602
#                vgg11    rmse              2.0  3.8326  2.4262  0.5848
# nPT            resnet10 rmse              2.0  4.6926  3.1456  0.7560
#                vgg11    rmse              2.0  3.8590  2.4544  0.6118
# nodif          resnet10 rmse              2.0  4.6950  3.0956  0.7408
#                vgg11    rmse              2.0  3.9268  2.4020  0.5650
#
#                                                    r2
# modality       model    checkpoint_type
# FA             resnet10 rmse             1.000000e-03
#                vgg11    rmse             3.412000e-01
# MD             resnet10 rmse             6.938894e-19
#                vgg11    rmse             3.256000e-01
# PT             resnet10 rmse            -2.800000e-03
#                vgg11    rmse             3.228000e-01
# T2s_1st_volume resnet10 rmse            -3.200000e-03
#                vgg11    rmse             3.006000e-01
# T2s_R2s        resnet10 rmse            -1.380000e-02
#                vgg11    rmse             3.310000e-01
# nPT            resnet10 rmse             2.200000e-03
#                vgg11    rmse             3.178000e-01
# nodif          resnet10 rmse            -2.000000e-04
#                vgg11    rmse             2.922000e-01

# %%
test_df
# Out:
#         model modality checkpoint_type  fold   rmse    mae   mape     r2
# 1       vgg11       FA            mape     0  5.152  3.177  0.452 -0.076
# 3    resnet10       FA            mape     0  5.595  2.929  0.348 -0.269
# 5       vgg11       FA            mape     1  4.982  2.867  0.379 -0.006
# 7    resnet10       FA            mape     1  5.798  3.198  0.386 -0.363
# 9       vgg11       FA            mape     2  4.649  2.762  0.392  0.124
# ..        ...      ...             ...   ...    ...    ...    ...    ...
# 131  resnet10  T2s_R2s            mape     2  5.773  3.152  0.379 -0.351
# 133     vgg11  T2s_R2s            mape     3  5.608  3.255  0.423 -0.275
# 135  resnet10  T2s_R2s            mape     3  5.763  3.139  0.375 -0.346
# 137     vgg11  T2s_R2s            mape     4  5.145  3.270  0.493 -0.073
# 139  resnet10  T2s_R2s            mape     4  5.710  3.067  0.362 -0.322
#
# [70 rows x 8 columns]

# %%
test_df = pd.read_csv("results/test_KidLeadRegression.csv")
test_df = test_df[test_df["checkpoint_type"] == 'mape']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                          fold    rmse     mae    mape      r2
# modality       model    checkpoint_type
# FA             resnet10 mape              2.0  5.8150  3.2130  0.3882 -0.3716
#                vgg11    mape              2.0  4.8486  2.9062  0.4058  0.0422
# MD             resnet10 mape              2.0  5.7536  3.1914  0.4038 -0.3486
#                vgg11    mape              2.0  5.0532  2.9960  0.4164 -0.0360
# PT             resnet10 mape              2.0  5.6044  2.9770  0.3618 -0.2744
#                vgg11    mape              2.0  5.1090  3.0276  0.4176 -0.0622
# T2s_1st_volume resnet10 mape              2.0  5.7454  3.1158  0.3716 -0.3382
#                vgg11    mape              2.0  4.8638  2.9002  0.4054  0.0382
# T2s_R2s        resnet10 mape              2.0  5.7252  3.0904  0.3682 -0.3286
#                vgg11    mape              2.0  5.1252  3.0686  0.4352 -0.0682
# nPT            resnet10 mape              2.0  5.5732  2.9870  0.3742 -0.2614
#                vgg11    mape              2.0  5.1672  3.0544  0.4186 -0.0836
# nodif          resnet10 mape              2.0  5.6718  3.0448  0.3660 -0.3048
#                vgg11    mape              2.0  4.7312  2.8708  0.4124  0.0868

# %%
test_df = pd.read_csv("results/val_KidLeadRegression.csv")
test_df = test_df[test_df["checkpoint_type"] == 'mape']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                          fold    rmse     mae    mape      r2
# modality       model    checkpoint_type
# FA             resnet10 mape              2.0  5.2530  2.7000  0.3848 -0.2866
#                vgg11    mape              2.0  4.5352  2.3252  0.3524  0.0656
# MD             resnet10 mape              2.0  5.1874  2.7004  0.3946 -0.2104
#                vgg11    mape              2.0  4.6328  2.4722  0.3942  0.0230
# PT             resnet10 mape              2.0  5.0678  2.5536  0.3800 -0.1624
#                vgg11    mape              2.0  4.6808  2.4700  0.3878 -0.0066
# T2s_1st_volume resnet10 mape              2.0  5.1898  2.6264  0.3726 -0.2356
#                vgg11    mape              2.0  4.5986  2.3734  0.3810  0.0382
# T2s_R2s        resnet10 mape              2.0  5.1812  2.5886  0.3642 -0.2404
#                vgg11    mape              2.0  4.6450  2.4814  0.3824  0.0020
# nPT            resnet10 mape              2.0  5.0322  2.5554  0.3878 -0.1418
#                vgg11    mape              2.0  4.7874  2.4974  0.3864 -0.0490
# nodif          resnet10 mape              2.0  5.1192  2.5610  0.3748 -0.1904
#                vgg11    mape              2.0  4.6092  2.3756  0.3630  0.0204

# %%
test_df = pd.read_csv("results/val_KidLeadRegression.csv")
test_df = test_df[test_df["checkpoint_type"] == 'r2']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                                fold    rmse     mae    mape  \
# modality       model          checkpoint_type
# FA             resnet10       r2                2.0  3.7870  2.3580  0.5356
#                resnet10_med3d r2                2.0  3.4882  2.4334  0.6246
#                vgg11          r2                2.0  3.4790  2.1746  0.5832
# MD             resnet10       r2                2.0  3.9152  2.4646  0.5704
#                resnet10_med3d r2                2.0  3.6494  2.4094  0.5760
#                vgg11          r2                2.0  3.4468  2.1840  0.5494
# PT             resnet10       r2                2.0  3.9136  2.5310  0.6222
#                resnet10_med3d r2                2.0  3.5230  2.3026  0.5746
#                vgg11          r2                2.0  3.2220  2.1542  0.5554
# T2s_1st_volume resnet10       r2                2.0  3.9126  2.2270  0.4702
#                resnet10_med3d r2                2.0  3.5428  2.4080  0.6002
#                vgg11          r2                2.0  3.6280  2.1322  0.4982
# T2s_R2s        resnet10       r2                2.0  3.8428  2.4622  0.5736
#                resnet10_med3d r2                2.0  3.6028  2.4406  0.5878
#                vgg11          r2                2.0  3.4638  2.2592  0.5808
# nPT            resnet10       r2                2.0  3.9556  2.3480  0.5136
#                resnet10_med3d r2                2.0  3.4952  2.3408  0.5690
#                vgg11          r2                2.0  3.4620  2.2876  0.5914
# nodif          resnet10       r2                2.0  3.8994  2.3156  0.5192
#                resnet10_med3d r2                2.0  3.6202  2.5676  0.6102
#                vgg11          r2                2.0  3.5480  2.2674  0.5710
#
#                                                    r2
# modality       model          checkpoint_type
# FA             resnet10       r2               0.3488
#                resnet10_med3d r2               0.3868
#                vgg11          r2               0.4456
# MD             resnet10       r2               0.2896
#                resnet10_med3d r2               0.3006
#                vgg11          r2               0.4496
# PT             resnet10       r2               0.2960
#                resnet10_med3d r2               0.3340
#                vgg11          r2               0.5042
# T2s_1st_volume resnet10       r2               0.3036
#                resnet10_med3d r2               0.3268
#                vgg11          r2               0.3978
# T2s_R2s        resnet10       r2               0.3234
#                resnet10_med3d r2               0.3424
#                vgg11          r2               0.4440
# nPT            resnet10       r2               0.2842
#                resnet10_med3d r2               0.3638
#                vgg11          r2               0.4546
# nodif          resnet10       r2               0.2922
#                resnet10_med3d r2               0.3246
#                vgg11          r2               0.4270

# %%
test_df = pd.read_csv("results/test_KidLeadRegression.csv")
test_df = test_df[test_df["checkpoint_type"] == 'r2']
r = test_df.groupby(["modality", "model", "checkpoint_type"]).mean()
r
# Out:
#                                                fold    rmse     mae    mape  \
# modality       model          checkpoint_type
# FA             resnet10       r2                2.0  3.8802  2.4996  0.4682
#                resnet10_med3d r2                2.0  4.7184  3.2798  0.6618
#                vgg11          r2                2.0  3.9300  2.3634  0.4320
# MD             resnet10       r2                2.0  3.9364  2.5348  0.4752
#                resnet10_med3d r2                2.0  4.7240  3.1592  0.6124
#                vgg11          r2                2.0  3.9640  2.3762  0.4314
# PT             resnet10       r2                2.0  3.9766  2.5714  0.4906
#                resnet10_med3d r2                2.0  4.8270  3.1264  0.6008
#                vgg11          r2                2.0  3.9652  2.5018  0.4772
# T2s_1st_volume resnet10       r2                2.0  3.9546  2.5012  0.4386
#                resnet10_med3d r2                2.0  4.5804  3.0704  0.6086
#                vgg11          r2                2.0  4.2214  2.5568  0.4286
# T2s_R2s        resnet10       r2                2.0  3.9312  2.5634  0.4860
#                resnet10_med3d r2                2.0  4.7874  3.3354  0.6372
#                vgg11          r2                2.0  3.8692  2.4442  0.4646
# nPT            resnet10       r2                2.0  3.8564  2.4710  0.4494
#                resnet10_med3d r2                2.0  4.6498  3.0256  0.5616
#                vgg11          r2                2.0  3.8854  2.4220  0.4566
# nodif          resnet10       r2                2.0  3.7296  2.4362  0.4410
#                resnet10_med3d r2                2.0  4.5860  3.1976  0.6210
#                vgg11          r2                2.0  3.8098  2.4636  0.4646
#
#                                                    r2
# modality       model          checkpoint_type
# FA             resnet10       r2               0.3864
#                resnet10_med3d r2               0.0904
#                vgg11          r2               0.3712
# MD             resnet10       r2               0.3660
#                resnet10_med3d r2               0.0902
#                vgg11          r2               0.3594
# PT             resnet10       r2               0.3576
#                resnet10_med3d r2               0.0536
#                vgg11          r2               0.3594
# T2s_1st_volume resnet10       r2               0.3626
#                resnet10_med3d r2               0.1452
#                vgg11          r2               0.2764
# T2s_R2s        resnet10       r2               0.3726
#                resnet10_med3d r2               0.0702
#                vgg11          r2               0.3924
# nPT            resnet10       r2               0.3962
#                resnet10_med3d r2               0.1162
#                vgg11          r2               0.3800
# nodif          resnet10       r2               0.4336
#                resnet10_med3d r2               0.1340
#                vgg11          r2               0.4068

# %%
pred = np.load("pred_KidLeadRegression _FA_resnet10_r2.npy")
label = np.load("labels_KidLeadRegression _FA_resnet10_r2.npy")

# %%
pred
# Out:
# array([ 6.14542818,  6.04789019,  5.28477955,  5.35202551, 10.33878613,
#         4.41850138,  3.2373991 ,  3.26621485,  5.11945391,  8.3594923 ,
#         4.10515547,  3.965276  ,  5.46193266,  2.78018379,  3.71682501,
#         4.38519859,  8.44021702,  4.60993099,  3.46209168,  4.12057304,
#         3.70242405,  7.88174105,  4.26499128,  4.0547204 ,  4.57088995])

# %%
label
# Out:
# array([ 3.72,  3.24,  2.88,  3.71, 12.93,  3.01,  2.91,  3.05,  2.74,
#        12.14,  3.56,  4.25,  4.16,  2.76,  2.61,  3.24, 22.83,  6.88,
#         4.34,  2.26,  4.61,  8.07,  3.97,  1.39,  2.89])

# %%
#create Bland-Altman plot                  
f, ax = plt.subplots(1, figsize = (8,5))
sm.graphics.mean_diff_plot(pred, label, ax = ax)

#display Bland-Altman plot
plt.show()

# %%
label
# Out:
# array([2.83821988, 2.07894206, 2.5129981 , 2.13565326, 2.48882174,
#        2.625458  , 3.39333391, 4.22192097, 1.91917336, 3.90521359,
#        2.99960518, 2.0937469 , 1.79071689, 2.96903038, 3.19824576,
#        5.25950956, 5.06644344, 2.1882081 , 2.59706092, 3.66202211,
#        3.17903471, 5.09589434, 2.12776566, 2.83900595, 4.00640488,
#        4.2831068 , 5.13669205, 3.65424752, 3.09005976, 6.82652998,
#        2.73373914])

# %%
import torch
from dataset import add_metrics_regression
from train import epoch_iter

# %%
model = get_model(model_name, device, n_classes = n_classes)
optimizer = torch.optim.SGD(model.parameters(), lr = lr)

# %%
device = 'cuda'


checkpoints_dir = f"checkpoints/{savepath}"

model_path = os.path.join(checkpoints_dir, f'model-{checkpoint_type}.ckpt')

model_state_dict = torch.load(model_path, map_location=torch.device(device))
model.load_state_dict(model_state_dict)

val_loss, preds_prob, labels = epoch_iter(test_loader, model, loss_function, optimizer, device, mode = 'test')
rmse, mae, mape, r2 = add_metrics_regression(preds_prob, labels)

results_test.append({
    'model': f"{model_name}",
    'modality':modality['modality'],
    'checkpoint_type': checkpoint_type,
    'fold': i_fold,
    'rmse': rmse,
    'mae': mae,
    'mape': mape,
    'r2': r2
})

val_loss, preds_prob, labels = epoch_iter(val_loader, model, loss_function, optimizer, device, mode = 'validation')
rmse, mae, mape, r2 = add_metrics_regression(preds_prob, labels)
results_val.append({
    'model': f"{model_name}",
    'modality':modality['modality'],
    'checkpoint_type': checkpoint_type,
    'fold': i_fold,
    'rmse': rmse,
    'mae': mae,
    'mape': mape,
    'r2': r2
})
